# %%
import numpy as np
import pandas as pd
import math
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Drug3000.csv')
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
df.shape
# Out:
# (3000, 6)

# %%
df.dtypes
# Out:
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %%
df.describe()
# Out:
#                Age      Na_to_K
# count  3000.000000  3000.000000
# mean     44.323000    16.872018
# std      16.625868     7.492906
# min      13.000000     5.885000
# 25%      31.000000    11.065000
# 50%      45.000000    14.642000
# 75%      58.000000    20.693000
# max      75.000000    39.247000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
ls = ['Sex', 'BP', 'Cholesterol']

for i in ls:
    print(df[i].unique())
# Out:
# ['F' 'M']
# ['HIGH' 'LOW' 'NORMAL']
# ['HIGH' 'NORMAL']

# %%
sns.countplot(df['Sex'])
df['Sex'].value_counts()
# Out:
# M    1560
# F    1440
# Name: Sex, dtype: int64

# %%
sns.countplot(df['BP'])
df['BP'].value_counts()
# Out:
# HIGH      1147
# LOW        959
# NORMAL     894
# Name: BP, dtype: int64

# %%
sns.countplot(df['Cholesterol'])
df['Cholesterol'].value_counts()
# Out:
# HIGH      1554
# NORMAL    1446
# Name: Cholesterol, dtype: int64

# %%
print(df['Drug'].unique())
df['Drug'].value_counts()
# Out:
# ['drugY' 'drugC' 'drugX' 'drugA' 'drugB']
# drugY    1316
# drugX     796
# drugA     361
# drugB     269
# drugC     258
# Name: Drug, dtype: int64

# %%
df['Drug'].value_counts().plot.pie()

# %%
Drug_A = df[df['Drug']=='drugA']
Drug_A.head()
# Out:
#     Age Sex    BP Cholesterol  Na_to_K   Drug
# 17   43   M  HIGH        HIGH   13.972  drugA
# 36   32   M  HIGH      NORMAL    9.445  drugA
# 46   37   F  HIGH        HIGH   13.091  drugA
# 61   24   M  HIGH      NORMAL    9.475  drugA
# 66   29   M  HIGH        HIGH   12.856  drugA

# %%
print('No. of patients for DrugA: ',Drug_A['Drug'].count())
print("Durg_A is mainly sutiable for the people of age around",math.ceil(Drug_A['Age'].mean()))
# Out:
# No. of patients for DrugA:  361
# Durg_A is mainly sutiable for the people of age around 37

# %%
Drug_B = df[df['Drug']=='drugB']
Drug_B.head()
# Out:
#     Age Sex    BP Cholesterol  Na_to_K   Drug
# 31   74   M  HIGH        HIGH    9.567  drugB
# 41   58   F  HIGH      NORMAL   14.239  drugB
# 54   68   F  HIGH      NORMAL   10.189  drugB
# 56   65   M  HIGH      NORMAL   11.340  drugB
# 64   60   F  HIGH        HIGH   13.303  drugB

# %%
print('No. of patients for DrugB: ',Drug_B['Drug'].count())
print("Durg_B is mainly sutiable for the people of age around",math.ceil(Drug_B['Age'].mean()))
# Out:
# No. of patients for DrugB:  269
# Durg_B is mainly sutiable for the people of age around 61

# %%
Drug_C = df[df['Drug']=='drugC']
Drug_C.head()
# Out:
#     Age Sex   BP Cholesterol  Na_to_K   Drug
# 1    47   M  LOW        HIGH   13.093  drugC
# 2    47   M  LOW        HIGH   10.114  drugC
# 7    41   M  LOW        HIGH   11.037  drugC
# 10   47   F  LOW        HIGH   11.767  drugC
# 18   23   M  LOW        HIGH    7.298  drugC

# %%
print('No. of patients for DrugC: ',Drug_C['Drug'].count())
print("Durg_C is mainly sutiable for the people of age around",math.ceil(Drug_C['Age'].mean()))
# Out:
# No. of patients for DrugC:  258
# Durg_C is mainly sutiable for the people of age around 43

# %%
Drug_X = df[df['Drug']=='drugX']
Drug_X.head()
# Out:
#     Age Sex      BP Cholesterol  Na_to_K   Drug
# 3    28   F  NORMAL        HIGH    7.798  drugX
# 5    22   F  NORMAL        HIGH    8.607  drugX
# 14   50   F  NORMAL        HIGH   12.703  drugX
# 16   69   M     LOW      NORMAL   11.455  drugX
# 27   49   F  NORMAL      NORMAL    9.381  drugX

# %%
print('No. of patients for DrugX: ',Drug_X['Drug'].count())
print("Durg_X is mainly sutiable for the people of age around",math.ceil(Drug_X['Age'].mean()))
# Out:
# No. of patients for DrugX:  796
# Durg_X is mainly sutiable for the people of age around 45

# %%
Drug_Y = df[df['Drug']=='drugY']
Drug_Y.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 4   61   F     LOW        HIGH   18.043  drugY
# 6   49   F  NORMAL        HIGH   16.275  drugY
# 8   60   M  NORMAL        HIGH   15.171  drugY
# 9   43   M     LOW      NORMAL   19.368  drugY

# %%
print('No. of patients for DrugY: ',Drug_Y['Drug'].count())
print("Durg_Y is mainly sutiable for the people of age around",math.ceil(Drug_Y['Age'].mean()))
# Out:
# No. of patients for DrugY:  1316
# Durg_Y is mainly sutiable for the people of age around 44

# %%
sns.countplot(df['Drug'])

# %%
sns.boxplot(x='Drug', y='Age', data=df[['Age', 'Drug']])

# %%
for col in ['Sex', 'BP', 'Cholesterol', 'Drug']:
    plt.figure()
    sns.heatmap(pd.crosstab(df['Drug'],df[col]),annot=True, cmap="YlGnBu")

# %% [markdown]
# ## Handling categorical values

# %%
data_arr = df[['Age', 'Sex', 'BP', 'Cholesterol', 'Drug']].values
data_arr[0:5]
# Out:
# array([[23, 'F', 'HIGH', 'HIGH', 'drugY'],
#        [47, 'M', 'LOW', 'HIGH', 'drugC'],
#        [47, 'M', 'LOW', 'HIGH', 'drugC'],
#        [28, 'F', 'NORMAL', 'HIGH', 'drugX'],
#        [61, 'F', 'LOW', 'HIGH', 'drugY']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

lb.fit(['M','F'])
data_arr[:,1] = lb.transform(data_arr[:,1])
data_arr[0:5]
# Out:
# array([[23, 0, 'HIGH', 'HIGH', 'drugY'],
#        [47, 1, 'LOW', 'HIGH', 'drugC'],
#        [47, 1, 'LOW', 'HIGH', 'drugC'],
#        [28, 0, 'NORMAL', 'HIGH', 'drugX'],
#        [61, 0, 'LOW', 'HIGH', 'drugY']], dtype=object)

# %%
lb.fit(['HIGH','LOW', 'NORMAL'])
data_arr[:,2] = lb.transform(data_arr[:,2])

lb.fit(['HIGH','NORMAL'])
data_arr[:,3] = lb.transform(data_arr[:,3])


lb.fit(['drugA','drugB', 'drugC', 'drugX', 'drugY'])
data_arr[:,4] = lb.transform(data_arr[:,4])
data_arr[0:5]
# Out:
# array([[23, 0, 0, 0, 4],
#        [47, 1, 1, 0, 2],
#        [47, 1, 1, 0, 2],
#        [28, 0, 2, 0, 3],
#        [61, 0, 1, 0, 4]], dtype=object)

# %%
data_arr = data_arr.astype('int')
data_arr[0:5]
# Out:
# array([[23,  0,  0,  0,  4],
#        [47,  1,  1,  0,  2],
#        [47,  1,  1,  0,  2],
#        [28,  0,  2,  0,  3],
#        [61,  0,  1,  0,  4]])

# %%
final_df = pd.DataFrame(data_arr)
final_df.head()
# Out:
#     0  1  2  3  4
# 0  23  0  0  0  4
# 1  47  1  1  0  2
# 2  47  1  1  0  2
# 3  28  0  2  0  3
# 4  61  0  1  0  4

# %%
final_df = pd.concat([final_df, df['Na_to_K']], axis = 1)
final_df.head()
# Out:
#     0  1  2  3  4  Na_to_K
# 0  23  0  0  0  4   25.355
# 1  47  1  1  0  2   13.093
# 2  47  1  1  0  2   10.114
# 3  28  0  2  0  3    7.798
# 4  61  0  1  0  4   18.043

# %%
col = ['Age', 'Sex', 'BP', 'Cholesterol', 'Drug', 'Na_to_K']
final_df.columns = col
final_df.head()
# Out:
#    Age  Sex  BP  Cholesterol  Drug  Na_to_K
# 0   23    0   0            0     4   25.355
# 1   47    1   1            0     2   13.093
# 2   47    1   1            0     2   10.114
# 3   28    0   2            0     3    7.798
# 4   61    0   1            0     4   18.043

# %%
final_df.dtypes
# Out:
# Age              int32
# Sex              int32
# BP               int32
# Cholesterol      int32
# Drug             int32
# Na_to_K        float64
# dtype: object

# %%
final_df.corr()
# Out:
#                   Age       Sex        BP  Cholesterol      Drug   Na_to_K
# Age          1.000000  0.090634  0.050460    -0.060640 -0.010478 -0.064651
# Sex          0.090634  1.000000 -0.015808    -0.002564 -0.088458 -0.106716
# BP           0.050460 -0.015808  1.000000    -0.128504  0.339272 -0.125143
# Cholesterol -0.060640 -0.002564 -0.128504     1.000000  0.062582  0.009990
# Drug        -0.010478 -0.088458  0.339272     0.062582  1.000000  0.493869
# Na_to_K     -0.064651 -0.106716 -0.125143     0.009990  0.493869  1.000000

# %%
corrmat = final_df.corr()
top_feature = corrmat.index
plt.figure(figsize=(15, 10))

hm = sns.heatmap(final_df[top_feature].corr(), annot=True, cmap="RdYlGn")

# %%
sns.pairplot(final_df)

# %% [markdown]
# ## Training/ Testing split dataset

# %%
final_df.head()
# Out:
#    Age  Sex  BP  Cholesterol  Drug  Na_to_K
# 0   23    0   0            0     4   25.355
# 1   47    1   1            0     2   13.093
# 2   47    1   1            0     2   10.114
# 3   28    0   2            0     3    7.798
# 4   61    0   1            0     4   18.043

# %%
X = final_df[['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K']].values
X[0:5]
# Out:
# array([[23.   ,  0.   ,  0.   ,  0.   , 25.355],
#        [47.   ,  1.   ,  1.   ,  0.   , 13.093],
#        [47.   ,  1.   ,  1.   ,  0.   , 10.114],
#        [28.   ,  0.   ,  2.   ,  0.   ,  7.798],
#        [61.   ,  0.   ,  1.   ,  0.   , 18.043]])

# %%
y = final_df['Drug'].values
y[0:5]
# Out:
# array([4, 2, 2, 3, 4])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2100, 5)
# (900, 5)
# (2100,)
# (900,)

# %% [markdown]
# ## Modeling and Evalution

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
j=[]
f=[]
for i in range(1, 10):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pre = knn.predict(X_test)
    j.append(jaccard_score(y_pre, y_test, average='micro'))
    f.append(f1_score(y_pre, y_test, average='micro'))

# %%
xx = np.arange(1,10,1)
plt.plot(xx, j, 'r')
plt.title('Jaccard Accuracy graph')
plt.xlabel('k')
plt.ylabel('Accuracy')
print("The highest the jaccard score - the better the performance")
print("The highest accuracy (",round(max(j), 3),") we got at k= ", (j.index(max(j)))+1)
# Out:
# The highest the jaccard score - the better the performance
# The highest accuracy ( 0.877 ) we got at k=  4

# %%
plt.plot(xx, f, 'r')
plt.title('f1 score Accuracy graph')
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.show

print("The Highest the f1 score - the better the performance")
print("The Highest accuracy (",'%.3f'%max(f),") we got at k= ", (f.index(max(f)))+1)
# Out:
# The Highest the f1 score - the better the performance
# The Highest accuracy ( 0.934 ) we got at k=  4

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
y_pre = knn.predict(X_test)

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
   
    plt.imshow(cm, cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm_knn = confusion_matrix(y_pre, y_test, labels = [0,1,2,3,4])
cr_knn = classification_report(y_pre, y_test)

print(cr_knn)
f1_knn = f1_score(y_pre, y_test, average='micro')
print("The f1 score of this model is: ", round(f1_knn, 3))

plt.figure()
plot_confusion_matrix(cm_knn, classes=['drugA','drugB','drugC','drugX','drugY'],normalize= False,  title='Confusion matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92        97
#            1       0.87      0.92      0.89        77
#            2       0.78      0.90      0.83        67
#            3       0.94      0.96      0.95       243
#            4       0.98      0.93      0.95       416
#
#     accuracy                           0.93       900
#    macro avg       0.90      0.93      0.91       900
# weighted avg       0.94      0.93      0.94       900
#
# The f1 score of this model is:  0.934

# %%
A_knn = accuracy_score(y_pre, y_test)
print("KNN's Accuracy: ", round(A_knn, 3))
# Out:
# KNN's Accuracy:  0.934

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
drug_tree = DecisionTreeClassifier(criterion="entropy", max_depth=4)
drug_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
yTre_pre = drug_tree.predict(X_test)
yTre_pre[0:5]
# Out:
# array([4, 3, 4, 4, 4])

# %%
from IPython.display import Image  
from sklearn import tree
import pydotplus

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
dot_data = tree.export_graphviz(drug_tree, out_file=None, 
                                feature_names=['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K'],  
                                class_names=['drugA', 'drugB', 'drugC', 'drugX', 'drugY'])

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)  

# Show graph
Image(graph.create_png())

# %%
j_tree = jaccard_score(yTre_pre, y_test, average='micro')
print("The jaccard similarity score of this model is: ", round(j_tree, 3))
# Out:
# The jaccard similarity score of this model is:  0.883

# %%
cm_tree = confusion_matrix(yTre_pre, y_test, labels = [0,1,2,3,4])
cr_tree = classification_report(yTre_pre, y_test)

print(cr_tree)
f1_tree = f1_score(yTre_pre, y_test, average='micro')
print("The f1 score of this model is: ", round(f1_tree,3))

plt.figure()
plot_confusion_matrix(cm_tree, classes=['drugA','drugB','drugC','drugX','drugY'],normalize= False,  title='Confusion matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        93
#            1       0.84      0.93      0.88        74
#            2       0.79      0.95      0.87        64
#            3       0.96      0.98      0.97       244
#            4       0.98      0.91      0.95       425
#
#     accuracy                           0.94       900
#    macro avg       0.89      0.94      0.92       900
# weighted avg       0.94      0.94      0.94       900
#
# The f1 score of this model is:  0.938

# %%
A_tree = round(accuracy_score(yTre_pre, y_test), 3)
print("Decision's Accuracy: ", A_tree)
# Out:
# Decision's Accuracy:  0.938

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
drug_log = LogisticRegression(C=0.01, solver='liblinear')
drug_log.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.01, solver='liblinear')

# %%
yLog_pre = drug_log.predict(X_test)
yLog_pre[0:5]
# Out:
# array([4, 3, 4, 4, 4])

# %%
j_log = jaccard_score(yLog_pre, y_test, average='micro')
print("The jaccard similarity score of this model is: ", j_log)
# Out:
# The jaccard similarity score of this model is:  0.5693112467306015

# %%
cm_log = confusion_matrix(yLog_pre, y_test, labels=[0,1,2,3,4])
cr_log = classification_report(yLog_pre, y_test, zero_division=0)

print(cr_log)
f1_log = f1_score(yLog_pre, y_test, average='micro')
print("The f1 score of this model is: ", round(f1_log,3))

plt.figure()
plot_confusion_matrix(cm_log, classes=['drugA','drugB','drugC','drugX','drugY'],normalize= False,  title='Confusion matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.04      1.00      0.08         4
#            1       0.66      0.61      0.64        88
#            2       0.00      0.00      0.00         0
#            3       0.89      0.80      0.84       277
#            4       0.95      0.70      0.81       531
#
#     accuracy                           0.73       900
#    macro avg       0.51      0.62      0.47       900
# weighted avg       0.90      0.73      0.80       900
#
# The f1 score of this model is:  0.726

# %%
A_log = round(accuracy_score(yLog_pre, y_test), 3)
print("Logistic Regression's Accuracy: ", A_log)
# Out:
# Logistic Regression's Accuracy:  0.726

# %% [markdown]
# ### GridSeacrhCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'saga']

c_values = [100, 10, 1.0, 0.1, 0.01]

# %%
grid = dict(solver=solvers,C=c_values)

grid_search = GridSearchCV(estimator=drug_log, param_grid=grid, n_jobs=-1, scoring='accuracy')
grid_result = grid_search.fit(X, y)

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.887333 using {'C': 100, 'solver': 'newton-cg'}

# %%
data = [[round(A_knn, 3), round(max(j), 3) ,round(max(f), 3)], [A_tree, round(j_tree, 3), round(f1_tree, 3)], [A_log, round(j_log, 3), round(f1_log, 3)]]

table = pd.DataFrame(data, columns=['Accuracy', 'Jaccard score', 'F1 score'], index = ['KNN', 'Decision', 'Logistic'])
table
# Out:
#           Accuracy  Jaccard score  F1 score
# KNN          0.934          0.877     0.934
# Decision     0.938          0.883     0.938
# Logistic     0.726          0.569     0.726

# %% [markdown]
# ### The best classification algorithm sutaible for this dataset to predict the drug is DESICION TREE

# %% [markdown]
# ## Exporting file

# %%
import pickle

# %%
pickle.dump(drug_tree, open('Medical_file.pkl', 'wb'))
